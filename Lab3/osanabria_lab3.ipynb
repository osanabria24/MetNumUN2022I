# %% [markdown]
# <a href="https://colab.research.google.com/github/osanabria24/MetNumUN2022I/blob/main/Lab3/osanabria_lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Analysis with Python
# ![Data Analysis with Python.png](data:image/png;base64,...)
#
# #Data Visualization with Python
# ![Data Visualization with Python.png](data:image/png;base64,...)
# #Python 101 For Data Science
# ![Python 101 For Data Science.png](data:image/png;base64,...)
